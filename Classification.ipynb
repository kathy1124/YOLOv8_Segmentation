# %% [markdown]
# <a href="https://colab.research.google.com/github/kathy1124/YOLOv8_Segmentation/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/MuhammadMoin97/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd /content/ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install -e .'[dev]'
# Out:
# Obtaining file:///content/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.3
#     Uninstalling ultralytics-8.0.3:
#       Successfully uninstalled ultralytics-8.0.3
#   Running setup.py develop for ultralytics
# ...

# %%
# %cd /content/ultralytics/ultralytics/yolo/v8/segment
# Out:
# /content/ultralytics/ultralytics/yolo/v8/segment

# %%
# !pwd
# Out:
# /content/ultralytics/ultralytics/yolo/v8/segment

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3V0dDFy4Srmx0xfN0b0R")
project = rf.workspace("classification-btt2b").project("class-edysx")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
HOME = "/content/ultralytics/ultralytics/yolo/v8/segment"

# %%
dataset.location
# Out:
# '/content/ultralytics/ultralytics/yolo/v8/segment/class-1'

# %%
# !pip install --upgrade "pillow<10.0"

# %%
# %cd {HOME}

# !python train.py model=yolov8l-seg.pt data={dataset.location}/data.yaml epochs=120 imgsz=640
# Out:
# /content/ultralytics/ultralytics/yolo/v8/segment
# ...
# 100% 88.1M/88.1M [00:01<00:00, 52.4MB/s]
#
# ...

# %%
# !ls /content/ultralytics/runs/segment/train
# Out:
# args.yaml					    MaskP_curve.png	 train_batch1432.jpg
# BoxF1_curve.png					    MaskPR_curve.png	 train_batch1.jpg
# BoxP_curve.png					    MaskR_curve.png	 train_batch2.jpg
# BoxPR_curve.png					    predictions.json	 val_batch0_labels.jpg
# BoxR_curve.png					    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 weights
# events.out.tfevents.1740882564.802bf2b74da7.3988.0  train_batch0.jpg
# MaskF1_curve.png				    train_batch1431.jpg

# %%
# !python val.py model='/content/ultralytics/runs/segment/train/weights/best.pt' data={dataset.location}/data.yaml
# Out:
# 2025-03-02 03:13:46.930815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740885226.959460   18707 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740885226.968218   18707 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-02 03:13:47.006709: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
Image("/content/ultralytics/runs/segment/train/val_batch0_pred.jpg")

# %%
Image("/content/ultralytics/runs/segment/train/results.png")

# %%
# !zip -r /content/ultralytics.zip /content/ultralytics
# Out:
#   adding: content/ultralytics/ (stored 0%)
#   adding: content/ultralytics/setup.py (deflated 56%)
#   adding: content/ultralytics/LICENSE (deflated 66%)
#   adding: content/ultralytics/docs/ (stored 0%)
#   adding: content/ultralytics/docs/hub.md (deflated 57%)
#   adding: content/ultralytics/docs/reference/ (stored 0%)
#   adding: content/ultralytics/docs/reference/exporter.md (deflated 13%)
#   adding: content/ultralytics/docs/reference/base_pred.md (deflated 34%)
#   adding: content/ultralytics/docs/reference/model.md (stored 0%)
#   adding: content/ultralytics/docs/reference/base_val.md (deflated 34%)
#   adding: content/ultralytics/docs/reference/base_trainer.md (deflated 33%)
#   adding: content/ultralytics/docs/reference/nn.md (deflated 41%)
#   adding: content/ultralytics/docs/reference/ops.md (deflated 87%)
#   adding: content/ultralytics/docs/index.md (deflated 59%)
#   adding: content/ultralytics/docs/config.md (deflated 74%)
# ...

# %%
from google.colab import files
files.download('/content/ultralytics.zip')
